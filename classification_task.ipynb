# %%
import numpy as np
import pandas as pd
import gzip
import json

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.feature_extraction.text import TfidfVectorizer

from sklearn.ensemble import VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from xgboost import XGBClassifier

from imblearn.over_sampling import SMOTE
import re
import nltk
from nltk.corpus import stopwords

# %%
# Data loading
train_classification_df = pd.read_csv(r"C:\Users\irmak\OneDrive\Masaüstü\412p\train-classification.csv")
train_classification_df = train_classification_df.rename(columns={'Unnamed: 0': 'user_id', 'label': 'category'})

# Unifying labels
train_classification_df["category"] = train_classification_df["category"].apply(str.lower)
username2_category = train_classification_df.set_index("user_id").to_dict()["category"]

# %%
# uploas JSONL data 
train_data_path = r"C:\Users\irmak\OneDrive\Masaüstü\412p\training-dataset.jsonl.gz"

username2posts_train = dict()
username2profile_train = dict()
username2posts_test = dict()
username2profile_test = dict()

with gzip.open(train_data_path, "rt") as fh:
    for line in fh:
        sample = json.loads(line)
        profile = sample["profile"]
        username = profile["username"]
        if username in username2_category:
            username2posts_train[username] = sample["posts"]
            username2profile_train[username] = profile
        else:
            username2posts_test[username] = sample["posts"]
            username2profile_test[username] = profile

# %%
def preprocess_text(text: str):
    if not isinstance(text, str):
        return ''
    
    # Preserve emojis - these might be important classification markers
    # Replace URLs with a special token
    text = re.sub(r'http\S+|www\S+|https\S+', '[URL]', text, flags=re.MULTILINE)
    
    # Preserve hashtags but remove the '#' symbol
    text = re.sub(r'#(\w+)', r'\1', text)
    
    # Replace mentions with a special token
    text = re.sub(r'@\w+', '[MENTION]', text)
    
    # Preserve numbers
    text = text.lower()
    
    return text

# %%
def extract_profile_features(username2profile):
    features = []
    for username, profile in username2profile.items():
        feature_dict = {
            'follower_count': profile.get('follower_count', 0),
            'following_count': profile.get('following_count', 0),
            'is_business_account': int(profile.get('is_business_account', False)),
            'is_private': int(profile.get('is_private', False)),
            'is_verified': int(profile.get('is_verified', False)),
            'follower_following_ratio': profile.get('follower_count', 0) / (profile.get('following_count', 1) + 1),
        }
        features.append(feature_dict)
    return pd.DataFrame(features)

# %%
# Prepare post texts
def prepare_post_texts(username2posts):
    texts = []
    for username, posts in username2posts.items():
        user_texts = []
        for post in posts:
            caption = post.get('caption', '')
            if caption:
                # Clean the caption text using the preprocessing function
                cleaned_caption = preprocess_text(caption)
                if cleaned_caption:
                    user_texts.append(cleaned_caption)
        # Combine all cleaned captions of a user into a single string
        texts.append(' '.join(user_texts))
    return texts

# %%
# Importing Turkish StopWords
import nltk
from nltk.corpus import stopwords

# Download the stopwords list from NLTK
nltk.download('stopwords')
turkish_stopwords = stopwords.words('turkish')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\irmak\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
post_texts_train = prepare_post_texts(username2posts_train)
vectorizer = TfidfVectorizer(
    stop_words=turkish_stopwords,
    max_features=5000,
    ngram_range=(1, 2),
    min_df=2,
    max_df=0.95
)
x_post_train = vectorizer.fit_transform(post_texts_train)

# %%
# Profile features
profile_features_train = extract_profile_features(username2profile_train)
scaler = StandardScaler()
profile_features_scaled = scaler.fit_transform(profile_features_train)

# Combine features
x_train_combined = np.hstack([
    x_post_train.toarray(),
    profile_features_scaled
])

# %%
# Retrieve usernames for the training data
train_usernames = list(username2posts_train.keys())

# Label encoding
label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform([username2_category.get(uname, "NA") for uname in train_usernames])

# %%
# Train-validation split
x_train, x_val, y_train_split, y_val = train_test_split(
    x_train_combined,
    y_train_encoded,
    test_size=0.2,
    stratify=y_train_encoded,
    random_state=42
)

# %%
# apply SMOTE
smote = SMOTE(random_state=42)
x_train_resampled, y_train_resampled = smote.fit_resample(x_train, y_train_split)

# %%
models = [
    ('lr', LogisticRegression(
        max_iter=1000,
        multi_class='multinomial',
        random_state=42
    )),
    ('svc', SVC(
        probability=True,  # for Soft voting probability=True
        kernel='linear',   
        random_state=42,
        max_iter=1000
    )),
    ('xgb', XGBClassifier(
        n_estimators=100,
        learning_rate=0.1,
        max_depth=7,
        objective='multi:softprob',
        random_state=42
    ))
]

# %%
# Voting Classifier
ensemble = VotingClassifier(
    estimators=models,
    voting='soft'  # soft voting
)

# Model training
ensemble.fit(x_train_resampled, y_train_resampled)
# Out:
# C:\Users\irmak\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\irmak\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# VotingClassifier(estimators=[('lr',
#                               LogisticRegression(max_iter=1000,
#                                                  multi_class='multinomial',
#                                                  random_state=42)),
#                              ('svc',
#                               SVC(kernel='linear', max_iter=1000,
#                                   probability=True, random_state=42)),
#                              ('xgb',
#                               XGBClassifier(base_score=None, booster=None,
#                                             callbacks=None,
#                                             colsample_bylevel=None,
#                                             colsample_bynode=None,
#                                             colsample_bytree=None, device=None,
#                                             early_stopping_rou...
#                                             importance_type=None,
#                                             interaction_constraints=None,
#                                             learning_rate=0.1, max_bin=None,
#                                             max_cat_threshold=None,
#                                             max_cat_to_onehot=None,
#                                             max_delta_step=None, max_depth=7,
#                                             max_leaves=None,
#                                             min_child_weight=None, missing=nan,
#                                             monotone_constraints=None,
#                                             multi_strategy=None,
#                                             n_estimators=100, n_jobs=None,
#                                             num_parallel_tree=None,
#                                             objective='multi:softprob', ...))],
#                  voting='soft')

# %%
#  Evaluate Training Set Performance (only accuracy)
print("\nTraining Set Performance:")
y_train_pred = ensemble.predict(x_train)
train_acc = accuracy_score(y_train_split, y_train_pred)
print(f"Accuracy: {train_acc:.4f}")
# Out:
# Training Set Performance:
# Accuracy: 0.9827

# %%
#Evaluate Validation Set Performance
print("\nValidation Set Performance:")
y_val_pred = ensemble.predict(x_val)
val_acc = accuracy_score(y_val, y_val_pred)
print(f"Accuracy: {val_acc:.4f}")

print("\nDetailed Report for Validation Set:")
print(
    classification_report(
        label_encoder.inverse_transform(y_val),
        label_encoder.inverse_transform(y_val_pred)
    )
)
# Out:
# Validation Set Performance:
# Accuracy: 0.6521
#
# Detailed Report for Validation Set:
#                       precision    recall  f1-score   support
#
#                  art       0.23      0.08      0.12        38
#        entertainment       0.45      0.40      0.42        65
#              fashion       0.53      0.72      0.61        60
#                 food       0.86      0.87      0.87       102
#               gaming       0.00      0.00      0.00         3
# health and lifestyle       0.62      0.79      0.70       100
#     mom and children       0.71      0.40      0.51        30
#               sports       0.80      0.70      0.74        23
#                 tech       0.71      0.75      0.73        69
#               travel       0.67      0.64      0.66        59
#
#             accuracy                           0.65       549
#            macro avg       0.56      0.54      0.54       549
#         weighted avg       0.63      0.65      0.63       549
# C:\Users\irmak\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\irmak\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\irmak\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
# Preprocess test data to create 'test_usernames' and 'test_corpus'
test_corpus = prepare_post_texts(username2posts_test)
x_post_test = vectorizer.transform(test_corpus) 

profile_features_test_df = extract_profile_features(username2profile_test)  
profile_features_test_scaled = scaler.transform(profile_features_test_df)  

x_test_full = np.hstack([
    x_post_test.toarray(), 
    profile_features_test_scaled
])

test_usernames = list(username2posts_test.keys())

# %%
import json
from collections import Counter
import numpy as np

# 2a) Read the usernames from the file 'test-classification-round3.dat'
test_data_path = r"C:\Users\irmak\OneDrive\Masaüstü\412p\test-classification-round3.dat"
test_unames = []
with open(test_data_path, "rt", encoding="utf-8") as fh:
    for line in fh:
        test_unames.append(line.strip())

# 2b) Find the corresponding feature vector for each username
x_test = []
for uname in test_unames:
    try:
        # Check if the username is in the test set
        idx = test_usernames.index(uname)
        row_vector = x_test_full[idx]  # numpy array (1D)
        x_test.append(row_vector)
    except ValueError:
        # If not in the test set, check the training set
        try:
            idx = train_usernames.index(uname)
            row_vector = x_train_combined[idx]
            x_test.append(row_vector)
        except ValueError:
            # If not in either set, append a zero vector
            zero_vec = np.zeros((1, x_test_full.shape[1]))
            x_test.append(zero_vec[0])  # Add as 1D array using [0]

# 2c) Convert the list of arrays into a single 2D array
x_test = np.vstack(x_test)
print("x_test.shape:", x_test.shape)
# Out:
# x_test.shape: (1000, 5006)

# %%
# 3a) Make predictions using the model
test_pred = ensemble.predict(x_test)
test_pred_categories = label_encoder.inverse_transform(test_pred)

# 3b) Collect prediction results in a dictionary
output = {uname: category for uname, category in zip(test_unames, test_pred_categories)}

# 3c) Display results on the screen
print("\nPredictions:")
print("-" * 50)
for uname, category in output.items():
    print(f"{uname}: {category}")

# 3d) Display the distribution of predictions
prediction_counts = Counter(test_pred_categories)
print("\nPrediction Distribution:")
print("-" * 50)
for category, count in prediction_counts.most_common():
    print(f"{category}: {count}")

# 3e) Save predictions as a JSON file
output_json_path = r"C:\Users\irmak\OneDrive\Masaüstü\412p\prediction-classification-round3.json"
with open(output_json_path, "w", encoding='utf-8') as json_file:
    json.dump(output, json_file, ensure_ascii=False, indent=4)

print(f"\nPredictions have been successfully saved to '{output_json_path}'.")
# Out:
# Predictions:
# --------------------------------------------------
# livapastanesi: food
# barisgross: food
# tusasshop: fashion
# etolyadigital: tech
# tugrulonur: entertainment
# tulugozlu: health and lifestyle
# gokidy: mom and children
# cengizgumus_official: fashion
# krossbisiklet: sports
# haribochamallows: food
# ozatashipyard: travel
# yenisafak: entertainment
# iamsiddeshjadhav: art
# burcinterzioglu: entertainment
# steakhousegunaydin: food
# baselifeclub: health and lifestyle
# benismailyildirimm: health and lifestyle
# imuneksfarma: health and lifestyle
# dogakoyucatalca: food
# sena.sener: fashion
# kandilliborsarestaurant: food
# selamiersoyy: art
# deutz_fahr_turkey: food
# cevaheer: fashion
# tezatsanat: entertainment
# filtresizcom: art
# palomamarina_suites: travel
# westchocolatemarina: food
# sebnemcapa: travel
# rozetsepeti: entertainment
# ececesmioglu: fashion
# ustapidecitr: food
# gocaagonyali: health and lifestyle
# maestro.sanat.kursu: art
# oztayteksofficial: fashion
# imtolstoyevski: entertainment
# turkervip: travel
# rustik.rus.restorani: food
# guzellik_hemsiresi: health and lifestyle
# mehmetcikvakfi: health and lifestyle
# bruderturkiye: fashion
# brandingturkiye: tech
# dogushyilmaz: art
# crmbelediyesi: entertainment
# gcaturkiye: tech
# bskcemildeveci: health and lifestyle
# lokmanhekimhastaneleri: health and lifestyle
# trumpavm: health and lifestyle
# resimlimagnet_com: art
# ilaydaakdogan: fashion
# karincaproduksiyon: art
# ilkergodencemobilya: fashion
# semihasahin: fashion
# ogretmeninkaleminden_: mom and children
# narkoyjournal: travel
# kuzucu_mucevherat: fashion
# mmkmetalurji: tech
# okanyanmazcom: health and lifestyle
# silopibld: health and lifestyle
# cubocomtr: tech
# ahlatbld: health and lifestyle
# tarimoz: tech
# komunpub: food
# novax_gozluk_camlari: health and lifestyle
# tarkan: entertainment
# sefkatpeker: fashion
# kore_kultur_merkezi: entertainment
# gaiaandco: food
# bvbajans: tech
# esila_kids: fashion
# halisunasyoncoffee: food
# ecovero.turkey: fashion
# denizliotizmdernegi: health and lifestyle
# buckheadturkey: fashion
# karaman.bel.tr: health and lifestyle
# imoykukarayel: fashion
# celsuskitabevi: health and lifestyle
# sonerarica1: entertainment
# keyifbebesi: fashion
# vadistanbul: entertainment
# pivoraizmir: food
# aliyagciii: fashion
# bebebiyat: art
# erdqtr: travel
# mo_istanbul: travel
# mekpan_panel: health and lifestyle
# rotarttasarim: tech
# tc_giresunvaliligi: health and lifestyle
# yigitcaliskan_: entertainment
# craftdesignistanbul: fashion
# jciistanbul: health and lifestyle
# mustafakoleoglu: health and lifestyle
# ankarabbld: health and lifestyle
# staynewinn: travel
# hasvetmedikal: tech
# trendysidebeach: travel
# promosyonizmir: tech
# turkiyekickboksfederasyonu: sports
# tugcedural: fashion
# nestleturkiye: health and lifestyle
# bomotorsport: sports
# ahmetmaranki: health and lifestyle
# hayalevent: fashion
# ozelkonakhastanesi: health and lifestyle
# istanbul_halidunyasi: fashion
# adiyaman_park_avm: entertainment
# pillavidenizli: food
# annebebekdergisii: mom and children
# enmutluoldugumyer: entertainment
# alfaglb: tech
# erciyes.anadolu: health and lifestyle
# dytgozdembasarir: health and lifestyle
# sirenebelekhotel: travel
# ahbap: health and lifestyle
# uzmanturizm: entertainment
# cagdasonurozturk: entertainment
# globaldentaleskisehir: health and lifestyle
# kilicyarenn: fashion
# moisahne: entertainment
# thecitysuitestr: travel
# kayihanpala: health and lifestyle
# bilkenttiyatro: art
# kentmeydaniavm: food
# cnridentex: health and lifestyle
# kirencekaya_balikcisi: food
# getir: food
# etimesgutbld: health and lifestyle
# yigitpoyrazz: fashion
# gokcinarnecdet: entertainment
# abdullahozdemirbb: health and lifestyle
# babilkulesi_: entertainment
# remedassistance: travel
# mikronajans: entertainment
# huaweimobiletr: tech
# gezmedenbilemezsin: travel
# coskunaltun36: travel
# lebleukusadasi: travel
# schweppes_tr: entertainment
# pilatesannesi: health and lifestyle
# livingroomist: art
# transeshairtransplant: health and lifestyle
# duygubie: fashion
# mylittleponytr: fashion
# gupseo: mom and children
# erenoren: fashion
# kirmiziocakbasi: food
# duzcehalkmar: food
# unicosigorta: health and lifestyle
# gezginsincap: health and lifestyle
# erkek_bileklik_modelleri: fashion
# yapikredibomontiada: entertainment
# socratesbistro: food
# mutfaktayusufvar: food
# digitalagencynetwork: tech
# fiatkastamonugozde: tech
# brkhkmn: travel
# vaziyetcomtr: health and lifestyle
# lisebjkcom: sports
# sinanguler: sports
# mamaspapas.tr: mom and children
# generalmobile: fashion
# borusanlojistik: tech
# sana_turkiye: food
# viptrend.com.tr: tech
# artonistanbul: art
# sezergsm38: tech
# resoundturkiye: tech
# tiyatroyeniden_official: art
# barcintancan: entertainment
# kadindayanismavakfi: health and lifestyle
# serdarsandal35: health and lifestyle
# denizcanaktasofficial: entertainment
# gulben123: mom and children
# gezmelerdeyim: food
# gomecbelediyesi: sports
# serpilexclusive: fashion
# gsb_hatay: sports
# talyakizyurdu: travel
# aycasenbaskan: art
# mandolinyayinlari: art
# sadberkhanimmuzesi: art
# zamanebaba: health and lifestyle
# izzettinyilmaztr: health and lifestyle
# freshscarfs: fashion
# pasta34shop: food
# webajans: tech
# gci.tuerkei: travel
# esseklinik: health and lifestyle
# samuthatr: health and lifestyle
# ozelaydingoz: health and lifestyle
# iloveanalogue: art
# kadinlarfestivali: health and lifestyle
# braunhouseholdturkey: food
# este.foot: health and lifestyle
# uzmananahtar: entertainment
# yorglass: tech
# selcuklukongremerkezi: entertainment
# zerrintekindor: entertainment
# nihatcan11: health and lifestyle
# sarikizmadensuyu: health and lifestyle
# ekremcoskundoner: food
# ilhansen: fashion
# hacettepe_university: tech
# besiktasbelediyesi: health and lifestyle
# scaniatr: tech
# tosunpasaalacati: food
# tuna.food: food
# indirimlix: entertainment
# theurbangoat.ist: food
# kesfetmek_guzeldir: food
# beko_serdar: tech
# mgulluoglu: health and lifestyle
# muyashop: fashion
# serhanonat: entertainment
# alperenduymaz: entertainment
# tasarimgroup: art
# ege_koy_mahsulleri: food
# yamalioglumucevherat: fashion
# babylissturkiye: tech
# perlavista_avm: fashion
# dr.gokalpdizdar: health and lifestyle
# kadinkoalisyonu: health and lifestyle
# acemdenizyel: art
# turkerkilic: health and lifestyle
# gulsenbubikogluofficial: health and lifestyle
# yazyuceil: travel
# kapadokyazeppelin: travel
# ikbalkaya: health and lifestyle
# lastdoor_tr: health and lifestyle
# dengemerkezi: health and lifestyle
# edisdeposu: health and lifestyle
# akyuzmobilyaurfa: fashion
# solcugazete: entertainment
# avmorion: entertainment
# fizikseltiyatro: art
# gurmerehber: food
# gursubeltr: health and lifestyle
# sahanepazar: fashion
# swipeline: tech
# ahmethamdigork: health and lifestyle
# expertyol: health and lifestyle
# araskarafil: entertainment
# tepebasibeltr: entertainment
# kumpirbox: food
# hedefbeytotel: travel
# seyitaliofficial: health and lifestyle
# armonipark: fashion
# erzincansuleymankaraman: health and lifestyle
# cebirecep: health and lifestyle
# omsvibro: tech
# alacatibeachresort: travel
# elkon_official: tech
# kaan.sekban: entertainment
# flotalmirror: travel
# thelevanttahinier: food
# zodyakli: fashion
# beiniztv: entertainment
# mesutscl: entertainment
# umraniyebeltr: health and lifestyle
# muratacilimranli: health and lifestyle
# imamoglu.belediyesi: health and lifestyle
# jumbokunefetr: food
# gulgrupgayrimenkul: tech
# soyturkrabia: entertainment
# pekcetintemizlik: health and lifestyle
# psikezone: health and lifestyle
# donerci_serkan_usta: food
# mirdellav: travel
# iyigelir.biz: health and lifestyle
# durumle: food
# 3durak: art
# roofgamesstudio: tech
# konseptkutucom: mom and children
# uras.benlioglu: food
# yemekcom: food
# ipekozagan: health and lifestyle
# ozeltanyeri: mom and children
# hakkiakdenizz: fashion
# mekoglobal: tech
# datcabelediyesi: health and lifestyle
# tkdkordu: health and lifestyle
# yelkenrest: food
# suleymansarilar: health and lifestyle
# ___daire___: travel
# iremhlvcioglu: fashion
# uberkuloz: fashion
# fdnsirketlergrubu: health and lifestyle
# podyumsanatmahal: art
# 3eeemedya: entertainment
# akinyucel: health and lifestyle
# sky_uk: fashion
# kesifmekan: food
# whatupmell: food
# nedimkaplann: health and lifestyle
# ozdilekusakavm: entertainment
# trendmobilyacom: fashion
# beka_beka_anaokulu: entertainment
# turkiyedagcilik: sports
# leylasapmazz: sports
# turkistanpazari: health and lifestyle
# hyattregencyistanbulatakoy: travel
# gercekmutfak: food
# tolgasaritas: entertainment
# gayretmakina: tech
# gzonemag: entertainment
# lineersoft: tech
# desimerkez: tech
# tavukdunyasikariyer: food
# akgunwalker: entertainment
# didemeryarunlu: art
# asaspen.veratec: tech
# ezgi_basaran: art
# applegurgencler: tech
# turktraktorkariyer: tech
# nihatatli.tr: health and lifestyle
# guncesanattiyatrosu: art
# talha_karci: entertainment
# meltem.hastanesi: health and lifestyle
# diyetisyengamzealtinay: health and lifestyle
# canyucetas: entertainment
# kaanurgancioglu: entertainment
# gursueraykirtasiye: art
# dinersclubtr: travel
# stonebarizmir: food
# rocscoffee: food
# ayhancanguven: sports
# ezomola: entertainment
# unuttumsanmacom: fashion
# hotech_ecosystem: tech
# bingolbel: health and lifestyle
# cengizsemercio: health and lifestyle
# bskulgurgokhan_: health and lifestyle
# veritameyve: food
# bekiraltantr: health and lifestyle
# vmilor: food
# pylsmn: food
# duzceguvencomtr: travel
# argonotlar.sanat: art
# cilemakar: fashion
# novotel_bosphorus: travel
# yuncualimagazalari: fashion
# bahar_eli: art
# turkiyesualtisporlari: sports
# operaistanbul: mom and children
# rengarenkkanal: travel
# guronimobilya: art
# ktheventagency: tech
# lutfusavas: health and lifestyle
# cookluhayat: food
# birayetarapca: health and lifestyle
# buyukdere35: art
# milliyiyici: food
# muhikucom: health and lifestyle
# izmirekolhastanesi: health and lifestyle
# fundafashion: fashion
# dilart.design: tech
# eurovisn_turkey: entertainment
# ibrahim__varli: entertainment
# tarsusbelediyesi: health and lifestyle
# pinarhepyanimda: food
# sporsuncom: sports
# btginsaat: health and lifestyle
# izmiretkinlikhaberleri: travel
# akifergurumtr: health and lifestyle
# boztaspremium: fashion
# 3d_maket: art
# tekinozalit: fashion
# elvanreklamtr: health and lifestyle
# alikerimdiler: health and lifestyle
# tufanlarkuyumculuk: fashion
# sendeyapsana: entertainment
# arifibrahimoff: travel
# alpatayazilim: tech
# kasaphansteakhouse: food
# seturdutyfree: fashion
# ozkocengin: health and lifestyle
# novikovbodrum: travel
# yedibilgeler: food
# caddekultursanat: art
# weareomgteam: health and lifestyle
# bullentoz: entertainment
# huseyinkabisteke: entertainment
# takviyegiller: health and lifestyle
# herseyyanimda: tech
# _helinkandemir: health and lifestyle
# ipekpamuk: food
# gsb_erzincan: health and lifestyle
# seyirdernegi: art
# eformspormerkezi: sports
# hakansuer41: entertainment
# medicasimple: tech
# murat.besikci: mom and children
# zadevital: food
# gokhanozoguz: entertainment
# fishorg: food
# ahlparkavm: entertainment
# galipensarioglu: entertainment
# acarflowers: art
# selcuklubel: health and lifestyle
# onlembebekbezi: mom and children
# liqui_moly_turkey: tech
# magnumenerji: tech
# kulabelediyesi: health and lifestyle
# aleynaclsknn: entertainment
# ikicay: food
# lemonadeagency: tech
# unolezzetleri: food
# pelinyarr: fashion
# viastudio: tech
# hyattregencyizmir_istinyepark: travel
# mentos_tr: food
# meliskaracam: travel
# dedemankonyahotel: travel
# 01burdaavm: fashion
# minimokirtasiye: art
# pendikbelediyesi: travel
# arkas_spor: sports
# normholding: tech
# ahmetipeksucuklariafyon: food
# medyaevi_iletisim: health and lifestyle
# mbbkulturas: health and lifestyle
# byelergumus: fashion
# ozanyigitt: entertainment
# miniaturkmuzesi: art
# ozgeyagizz: fashion
# nanopax_com: tech
# roketsan: tech
# kadikoyemek: art
# ozaysendir: entertainment
# ferideozdincc: fashion
# ecift: health and lifestyle
# eklerciumit: food
# estehair: health and lifestyle
# izmirhim: health and lifestyle
# demiirhaan: health and lifestyle
# ketebe: art
# pozitif.dusunceler: health and lifestyle
# opdrerdemzengin: health and lifestyle
# gufojewelry: fashion
# hamzaefendi: food
# imok_studio: fashion
# ysdistanbul: art
# beachandbeyondswimwear: fashion
# richmondpamukkale: travel
# rizepazarbelediyesi: health and lifestyle
# vineturkiyem: entertainment
# ikizlerbebefethiye: mom and children
# trtworld: art
# ozgefiskin: entertainment
# engeenergy: tech
# biostoretr: food
# edakok59: entertainment
# avmpomelon: health and lifestyle
# sait.restaurant: food
# evimin.yemekleri: food
# ladymiena: mom and children
# dokusanatatolyesi: fashion
# alvisajanss: tech
# birunitiyatro: art
# ugursengulx: fashion
# kemerlizimba: tech
# drenginocal: health and lifestyle
# patara.well: health and lifestyle
# barbarosfarm: food
# ataguroffice: fashion
# ankaranobeltipkitabevleri: art
# arminesiirtpark: fashion
# bancocomtr: tech
# akbarkodetiket: tech
# karsiyakabelediyesi: health and lifestyle
# simaybarlass: entertainment
# erdogantok55: sports
# levonbagis: food
# quartzclinique: health and lifestyle
# porlandgastro: tech
# dyt.psk.bilgesakli: health and lifestyle
# dericompany: fashion
# keciorenbelediyesi06: health and lifestyle
# nergiscorakci: entertainment
# ontangrup: health and lifestyle
# katalportmarin: travel
# primemallantakya: entertainment
# umit_ozlale: health and lifestyle
# lokmacafe: food
# drhalilibrahimtekin: health and lifestyle
# deppo_avantaj: fashion
# meltem.kursunlu: health and lifestyle
# akhisarpresshaber: entertainment
# grisahne: art
# besaygold: fashion
# bungalovoteller: travel
# mersinsensin: food
# biancaboya: tech
# yegezokuyaz: travel
# cemseymen: health and lifestyle
# prohealthgenetictests: health and lifestyle
# erenkoy_danismanlik: health and lifestyle
# ayvalikescbilisim: tech
# thecompanytr: fashion
# iyigelecekelcileri: health and lifestyle
# nevzatozkur0: sports
# denizlibbld: entertainment
# cibalikapibalikcisi: food
# pak_metal: tech
# tavtechnologies: travel
# malatyapark: entertainment
# onurkuyumcu1919: fashion
# poyrazotomotiv: tech
# ninovaparkavm: fashion
# drderyacan: health and lifestyle
# primepuritypep: health and lifestyle
# galenikecza: health and lifestyle
# milangaz: health and lifestyle
# mediviasaglikgrubu: health and lifestyle
# tulayerciyaskayaa: health and lifestyle
# kurulusdizisi: entertainment
# nurgulyesilcayy: entertainment
# selinayalcn: entertainment
# calgontr: health and lifestyle
# mplusturkiye: tech
# antmarealacati: travel
# duzicibld: health and lifestyle
# assosdiamond: fashion
# gulseli.com.tr: fashion
# iremsak: health and lifestyle
# zulaoyun: entertainment
# ozdilekboluavm: fashion
# everfastenings: tech
# ozakgokturk: travel
# pelinkarahan: fashion
# kerimsabanci: entertainment
# fatmasamsayilmaz: travel
# drbrkzks: mom and children
# ciftelerbelediyesi: health and lifestyle
# serangocer: health and lifestyle
# hisliseyler: health and lifestyle
# richhousebistro: food
# nurullahsavasresmi: health and lifestyle
# yfatihcoban: health and lifestyle
# boschturkiyekariyer: tech
# yachtmurat: entertainment
# cetinkayapano: tech
# yoldabiblog: travel
# limak.hotels: travel
# eminoguzcelebi: travel
# sailturkiyeracing: sports
# kronospan: art
# defneilgaz.com.tr: entertainment
# seyfidingil: health and lifestyle
# atalaraleyna: fashion
# 253binyasin: entertainment
# tulinnalbayrak: food
# reiskuyumculuk: fashion
# dijiatolye: food
# antolojiankara: travel
# girafestore: fashion
# profdrmuratbas: health and lifestyle
# kendinemuzisyen: art
# didembalikofficial: health and lifestyle
# zpor: sports
# aquayasamofficial: health and lifestyle
# oguzhankapilar: entertainment
# westparkoutlet: entertainment
# odyomedbursa: health and lifestyle
# pluscomiletisim: tech
# ulubeybelediyesi: travel
# galvinnisantasi: food
# yoldalogistics: tech
# mesdokum: tech
# cizmecikedi: travel
# koleksiyonerberber: health and lifestyle
# gurhanaltundasar: art
# ankaragucufp: health and lifestyle
# technical_sharing: art
# idaorgonite: health and lifestyle
# virahabercom: entertainment
# uykudunyasicom: health and lifestyle
# beymenclub: fashion
# theboviera: travel
# logoyazilimkariyer: tech
# tijenaktay: food
# mastercardturkiye: food
# itef_istanbul: art
# buyukekerbijon: tech
# kosbsocial: health and lifestyle
# bisalt: food
# antmodern: health and lifestyle
# trendyolhizlimarket: food
# transparentproductions: tech
# acibadem.international: health and lifestyle
# mervekutlu: fashion
# dirim.metal: tech
# rahmi.gencer: health and lifestyle
# hamzayilmazmucevherat: fashion
# 1001sanat: entertainment
# gaziantepbeld: health and lifestyle
# aslanegegrup: tech
# sabanozubelediyesi: entertainment
# flotalofficial: tech
# guralpremier: travel
# debuttiyatro: art
# yorkkadikoy: food
# spitalispecialbahceci: fashion
# ecebelenn: entertainment
# ersinceliq: entertainment
# greysatelier: tech
# sarigolbelediyesi: travel
# umut.cigercisi: food
# ikuakingucoditoryumu: art
# tcvanvaliligi: health and lifestyle
# sivilsayfalar: health and lifestyle
# sestri.lifestyle: travel
# crafttiyatro: entertainment
# 1983beyoglu: food
# ardahalil: health and lifestyle
# sinemunsal: fashion
# baziseylertiyatrosu: art
# ipekkyazici: health and lifestyle
# junkeralsancak: food
# bihterkocc: fashion
# alinuraktas: health and lifestyle
# forkidstyle: fashion
# mesudiyelicom: fashion
# hurriyetkelebek: entertainment
# turktelekombasketbol: sports
# drselcukyuce: health and lifestyle
# andacyesilyurt: food
# yigitcanic: travel
# gulercetingoz: entertainment
# paktplus: fashion
# tiyatrokast: entertainment
# akutdernegi: health and lifestyle
# telesuresigorta: health and lifestyle
# aperinastudios: art
# yenicekoyu43: travel
# gencliksporbak: sports
# gittibu_com: fashion
# farukerdem: entertainment
# zamanekahvesi: food
# ismailsenol: sports
# senpilic: food
# alternatifmarket: entertainment
# sehernigiz: food
# ozulkutipmerkezi: health and lifestyle
# acunilicali: sports
# adnanturankb: health and lifestyle
# ckalebelediye: health and lifestyle
# nesrullah.tanglay: health and lifestyle
# aslieliftanugursamanci: health and lifestyle
# tonyhawk: sports
# pursuailesi: food
# call_me_mumsy: health and lifestyle
# kocamaar: food
# retinagraphic: art
# winblocktr: art
# multiplayertv: entertainment
# beyoglubld: health and lifestyle
# m0rtyrick: entertainment
# icindekocvar: tech
# gshocktr: fashion
# beykozkultursanat: entertainment
# ecmelsoylu: health and lifestyle
# tevadimadim: mom and children
# bursayasam: travel
# maden_belediyesi: health and lifestyle
# trgyguler: entertainment
# metanucreative: entertainment
# upl.turkey: tech
# celebizadeonline: tech
# uclermarket: food
# toyganavanoglu: entertainment
# agacin.izinde: tech
# ozhotelstr: travel
# safamecomercial: tech
# _felxtv_: entertainment
# dentsuadiye: health and lifestyle
# tiyatroboyalikus: art
# basaritelematik: health and lifestyle
# ciplakayaklarkumpanyasi: art
# mahmut_mirkelamm: health and lifestyle
# tekincreativemedia: tech
# tasovabelediyesi: health and lifestyle
# supra_hubs: entertainment
# mandalajans: food
# ebcinege: travel
# adilyildirimyazar: entertainment
# asiyansanat: health and lifestyle
# muharremakcadurak: health and lifestyle
# donercibekirzade: food
# sherwoodresorts: travel
# grandyaziciclubturban: travel
# birbuketmuge: food
# bozcaadabld: health and lifestyle
# dijitalsosyalmedyam: entertainment
# adel.turkiye: health and lifestyle
# benim.odam: fashion
# manolyaurkan: art
# donerciorhan: food
# akcoat_official: tech
# evimdeterapi: health and lifestyle
# zettdekor: fashion
# agrotar_turkey: health and lifestyle
# pasinlerbld: health and lifestyle
# tipografi: art
# nurettinsonmez: entertainment
# tubabustun.official: art
# 35likmeyhaneizmir: food
# stilac: entertainment
# boyrazizolasyon: health and lifestyle
# dentisteturkiye: health and lifestyle
# altinayteknoloji: tech
# avbakidemirbas: health and lifestyle
# diyeting: food
# superfitshoes_turkey: health and lifestyle
# diyetebasliyorumcom: food
# pizzastationturkiye: food
# adiyamanvalilik: health and lifestyle
# cevrecienerjidernegi: health and lifestyle
# novaarsaofficial: health and lifestyle
# rubisaglik: health and lifestyle
# denizbaysal_: entertainment
# drtubagunebak: health and lifestyle
# rotekstekstil: tech
# burkaystagram: entertainment
# yenisehir.bel.tr: entertainment
# pelinnarint: health and lifestyle
# partibutik: art
# simalcerenn: fashion
# buklatur: travel
# oxabrasive: tech
# marka.333: health and lifestyle
# gulsjourney: health and lifestyle
# gdz_edas: tech
# turyap: health and lifestyle
# ugurakkafa: health and lifestyle
# tiesfed: sports
# zabeyazgul: health and lifestyle
# fordotosan: tech
# sevilayyilman: art
# instakocaali: travel
# regispatent: tech
# lezzetborsasi: food
# netafimturkiye: tech
# evreninmatematigi: health and lifestyle
# seyhanlarmarket: entertainment
# relaxmodeofficial: fashion
# ataberk.dogan: gaming
# meliketatar: fashion
# tohumgubre: tech
# ebebek: mom and children
# mabbelsatolye: fashion
# hopiapp: health and lifestyle
# tariszeytinyagi: food
# tahsinhasoglu: entertainment
# longosphere: travel
# peymankuruyemis: food
# trendylarahotel: travel
# pedasled: tech
# besiktasshipyard: travel
# puccito: mom and children
# malatyakultursosyal: health and lifestyle
# sofosistanbul: art
# devrimyakut: art
# forevernewturkiye: fashion
# valigokmencicek_: mom and children
# akbanksanat: art
# isaleticom: tech
# veli.gok32: health and lifestyle
# trio_deniz_official: travel
# mcengizbozkurt: entertainment
# istanbulalpplastik: food
# pelinsutilki: entertainment
# iamemrecaliskan: health and lifestyle
# ismailgeduz: health and lifestyle
# selfycomtr: entertainment
# mstismakinalari: tech
# studio.oyunculari: entertainment
# nexuskuafor: fashion
# cznburak: entertainment
# etidanismanlik: tech
# yildizgaz: tech
# bademlebuduk: mom and children
# sayginbaykaracom: art
# onder.sayan: travel
# tiyatroumay: art
# maraskaski: health and lifestyle
# bebedorturkey: mom and children
# jumboturkiye: food
# alacabld: entertainment
# bs_forklift: health and lifestyle
# superfm: entertainment
# yagizkurtulusy: fashion
# yasemoz88: entertainment
# thermexturkiye: tech
# polarisayakkabi: fashion
# edremitbelediye: health and lifestyle
# dr.yasirgozu: health and lifestyle
# middelrestaurant: food
# mtmofamily: entertainment
# yelizyesilmen: health and lifestyle
# sumerpark_avm: travel
# sozerinsaatorhangazi: tech
# digitalaths: gaming
# gulcinsant: travel
# endlessaksuluayakkabi: fashion
# minisoturkey: fashion
# aysatiyatro: art
# artlineturkiye: art
# montel.official: art
# dizayngroup: tech
# asliafsaroglu: art
# karefilm: tech
# moc_coffeeofficial: food
# talyatasarimtr: tech
# arguvanbelediyesi: health and lifestyle
# cengelofficial: entertainment
# ekulak: art
# gokgunnec: health and lifestyle
# arzumkoyuncu: health and lifestyle
# fiyuutr: tech
# aynesgida: food
# oyuncusendika: health and lifestyle
# jehanbarbur: entertainment
# rafadantayfa: entertainment
# basf_tarim_tr: tech
# ardesenbelediyesi: health and lifestyle
# kuirfest: art
# olips_tr: entertainment
# muzegazhane: health and lifestyle
# ondibilisim: health and lifestyle
# gazihastanesi: health and lifestyle
# gelinevi_tv: fashion
# heyceyn: fashion
# tekhnelogos: tech
# petadijital: tech
# gustogiyim: fashion
# akasyaa_avm: tech
# arslangurerr: health and lifestyle
# dr.turhanguldas: entertainment
# orcundalarslan: travel
# alldaycharm: fashion
# mxnsturkey: food
# talaycihan: art
# kutuphane79: health and lifestyle
# sevketcoruh: entertainment
# aliyerlikaya_: entertainment
# sacimsacinolsun: health and lifestyle
# mhmtaktrk: health and lifestyle
# jessicamayofficial: entertainment
# ceturturkiye: health and lifestyle
# elifatalar: food
# profdrmurataksoy: health and lifestyle
# gastrogezgin: travel
# axisistanbulavm: entertainment
# petopytr: health and lifestyle
# berkaytulumbaci: art
# evdekolay: health and lifestyle
# viteltr: tech
# merveozbeyofficial: entertainment
# no224creative: tech
# goksu_avm: tech
# baharakinci: travel
# mengenbelediyesi1414: entertainment
# batuconcept: fashion
# ih_korkmaz: health and lifestyle
# piculetstore: fashion
# kadinozsavunma: health and lifestyle
# borckabld: entertainment
# biryemekiste: food
# evkokusu: health and lifestyle
# maison_turkey: travel
# ceyhanbeltr: health and lifestyle
# daricabelediyesi: health and lifestyle
# korayaydintr: health and lifestyle
# izmiretkinlikleri: entertainment
# labrandaephesusprincess: travel
# sanliurfabld: health and lifestyle
# eczacibasisporkulubu: sports
# gulrizandic: health and lifestyle
# mustafatokat77: health and lifestyle
# iqaluminiumsystems: tech
# carpetartofficial: art
# wcollection: fashion
# kutu.baligi: travel
# gimatmarketlerzincirii: food
# jalpersanofficial: art
# luleburgazbld: travel
# paragrafmedya: tech
# ozgurcamurlu: art
# ekimsanat: art
# fixgross: food
# konyafarukgulluoglu: food
# yiyomfoodblogger: food
# dorukyazilim: tech
# mantragastropub: food
# yudumyag: food
# kiralarsin: tech
# orhansef: food
# merterenbulbul1: entertainment
# antaresavm: health and lifestyle
# mutfakta_bebek_var: mom and children
# kaanvarli: entertainment
# finikebelediye: health and lifestyle
# brotherturkey: tech
# justfeelingstudio: health and lifestyle
# gezsenbatman: food
# yapimboyle: entertainment
# quickchina: food
# amazon.tr: fashion
# ihealthsaglik: health and lifestyle
# alicanaytekin: health and lifestyle
# elegansgrupkagitcilik: health and lifestyle
# elementlogistics: tech
# gumus_bahattin: health and lifestyle
# bengikurtcebe: food
# asyaalizaude: entertainment
# solargezi: health and lifestyle
# fevzizirhlioglu: health and lifestyle
# kozantepkunefe: food
# kasapoglu: entertainment
# fourestcalticak: travel
# altinorumcek: tech
# arzuakbaszor: health and lifestyle
# ahmettatlises: health and lifestyle
# didemsoydan: fashion
# acemmarket: food
# idasosyalmedya: entertainment
# pertekbelediyesi: health and lifestyle
# fixpacktr: tech
# feriyeistanbul: food
# okanerertugrul: food
# isikcelik.a.s: tech
# dpperfumum: fashion
# nilaybale: entertainment
# fahrigediz: food
# vanedremitbld: health and lifestyle
# ebruuyucell: entertainment
# menopozveyasamtr: health and lifestyle
# altekyapi: tech
# thermomixtr: food
# bitaksi: health and lifestyle
# antalyakultursanat: art
# sergenozn: food
# cemuzan: sports
# enka_insaat_official: tech
# socialbrandstr: tech
# alialtuntasbaskan: health and lifestyle
# silivritvtr: art
# vimerang: art
# omurgedik: entertainment
# richmondnua: health and lifestyle
# psikologmerkezi: health and lifestyle
# divan_sarraf: fashion
# baykushbaby: food
# kademe.tr: tech
# motolojim: health and lifestyle
# guven_ovun: health and lifestyle
# argoalsancak: entertainment
# kelambazblog: health and lifestyle
# grand_cevahir_hotel: travel
# aysebilgeselcuk: health and lifestyle
# dilekcesur_: entertainment
# agoraavm_antalya: entertainment
# tugkangonultas: entertainment
# roubloff_turkey: art
# prof.dr.halilalis: health and lifestyle
# driclortr: health and lifestyle
# tiyatroterminal: art
# cartmancase: tech
# farkyaratanlarsabancivakfi: health and lifestyle
# kosekahve: food
# kadikoyboasahne: entertainment
# kdzereglitso: health and lifestyle
# pepsiturkiye: entertainment
# estetikeskisehir: health and lifestyle
# itsumijapon: food
# dyt.omercanyorulmaz: food
# kucukkulup_: food
# tugrulkuyumculuk: fashion
# eczozgurozel: entertainment
# merrellturkiye: fashion
# rivadent_maltepe: health and lifestyle
# gastronometro: food
# seyhan_ekspres: entertainment
# minikseyler_: mom and children
# kasimpasask: sports
# otokiosktr: tech
# karasugold: fashion
# mostphotos: travel
# swothospitality: entertainment
# kuff.yeldegirmeni: food
# birceakalay: fashion
# aynurtartan: food
# brixtonturkiye: travel
# reklamcikafasi: entertainment
# utkucubukcuoglu: health and lifestyle
# ucan_baba: mom and children
# rehberle: travel
# ntaslicay: health and lifestyle
# dogukan_kilic: food
#
# Prediction Distribution:
# --------------------------------------------------
# health and lifestyle: 263
# entertainment: 148
# food: 136
# tech: 121
# fashion: 115
# travel: 83
# art: 82
# sports: 27
# mom and children: 23
# gaming: 2
#
# Predictions have been successfully saved to 'C:\Users\irmak\OneDrive\Masaüstü\412p\prediction-classification-round3.json'.
